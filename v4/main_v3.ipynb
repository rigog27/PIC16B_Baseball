# %%
# !python train.py
# Out:
# --- TRUE PITCH DISTRIBUTION (WITH BATTER STATS) ---
#  CU :  18.21% (626 pitches)
#  FC :  10.97% (377 pitches)
#  FF :  34.68% (1192 pitches)
#  FS :  26.01% (894 pitches)
#  SI :   7.24% (249 pitches)
#  SL :   2.85% (98 pitches)
#  ST :   0.03% (1 pitches)
#
# Saved train_games.npy and val_games.npy (30 train games, 8 val games).
# Epoch 01 | Train Loss 1.9713 | Val Loss 1.8917 | Train Acc 0.3347 | Val Acc 0.3401 *
# Epoch 02 | Train Loss 1.9250 | Val Loss 1.8283 | Train Acc 0.3561 | Val Acc 0.4157 *
# Epoch 03 | Train Loss 1.8501 | Val Loss 1.7209 | Train Acc 0.4332 | Val Acc 0.4709 *
# Epoch 04 | Train Loss 1.7611 | Val Loss 1.6706 | Train Acc 0.4882 | Val Acc 0.5233 *
# Epoch 05 | Train Loss 1.6684 | Val Loss 1.6002 | Train Acc 0.5220 | Val Acc 0.5596 *
# Epoch 06 | Train Loss 1.6011 | Val Loss 1.5913 | Train Acc 0.5671 | Val Acc 0.5669 *
# Epoch 07 | Train Loss 1.5335 | Val Loss 1.4842 | Train Acc 0.6082 | Val Acc 0.6235 *
# ...

# %%
# !python evaluate.py
# Out:
# OVERALL VALIDATION ACCURACY: 0.3948
#
# PER-PITCH ACCURACY:
#  CU : 0.0767  (n=626)
#  FC : 0.1777  (n=377)
#  FF : 0.5797  (n=1192)
#  FS : 0.4306  (n=894)
#  SI : 0.5703  (n=249)
#  SL : 0.2449  (n=98)
#  ST : 0.0000  (n=1)
#
# Saved confusion matrix to confusion_matrix_v2.png
